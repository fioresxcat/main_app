324, 1323, 1323, 1322, 1322, 1322, 1321, 1320, 1321, 1322, 1321, 1320, 1317, 1319, 1318, 1316, 1315, 1314, 1314, 1313, 1312, 1312, 1312, 1311, 1311, 1310, 1310, 1310, 1310, 1309, 1308, 1307, 1304, 1302, 1301, 1300, 1301, 1298, 1299, 1299, 1300, 1300, 1300, 1300, 1299, 1298, 1277, 1277, 1281, 1281, 1282, 1282, 1282, 1282, 1281, 1282, 1282, 1282, 1283, 1282, 1282, 1282, 1282, 1282, 1283, 1283, 1283, 1283, 1284, 1284, 1284, 1284, 1284, 1284, 1284, 1284, 1284, 1285, 1285, 1285, 1285, 1285, 1286, 1286, 1286, 1286, 1286, 1286, 1286, 1286, 1286, 1286, 1286, 1286, 1286, 1286, 1287, 1288, 1288, 1289, 1289, 1289, 1289, 1289, 1289, 1289, 1290, 1291, 1291, 1291, 1292, 1293, 1293, 1293, 1293, 1293, 1294, 1294, 1294, 1294, 1295, 1294, 1295, 1295, 1295, 1295, 1296, 1296, 1296, 1296, 1297, 1297, 1297, 1297, 1297, 1297, 1297, 1297, 1297, 1297, 1298, 1298, 1298, 1298, 1298, 1298, 1299, 1299, 1299, 1299, 1299, 1299, 1300, 1300, 1300, 1301, 1301, 1302, 1302, 1302, 1302, 1297, 1295, 1294, 1302, 1304, 1304, 1303, 1302, 1302, 1303, 1304, 1304, 1304, 1305, 1304, 1305, 1304, 1305, 1306, 1307, 1306, 1325, 1326, 1325, 1325, 1325, 1327, 1326, 1327, 1337, 1339, 1345, 1349, 1350, 1349, 1348, 1351, 1351, 1350, 1357, 1358, 1358, 1359, 1358, 1360, 1362, 1361, 1361, 1361, 1361, 1360, 1361, 1362, 1362, 1362, 1362, 1362, 1362, 1362, 1362, 1362, 1362, 1362, 1362, 1363, 1366, 1367, 1367, 1370, 1371, 1371, 1373, 1374, 1375, 1376, 1378, 1379, 1380, 1384, 1384, 1385, 1239, 1332, 1325, 1314, 1234, 1298, 1236, 1277, 1267, 1253, 1242, 1235, 1228, 1215, 1206, 1196, 1185, 1179, 1170, 1160, 1153, 1144, 1136, 1127, 1118, 1110, 1100, 1092, 1084, 1076, 1058, 1050, 1031, 1012, 1003, 993, 983, 975, 967, 956, 949, 940, 930, 921, 913, 903, 894, 883]
fr_indices = [176, 178, 179, 180, 181, 182, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 208, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 398, 399, 400, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 530, 531, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 637, 638, 639, 640, 641, 642, 643, 646, 647, 648, 649, 650, 651, 679, 680, 681, 690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 771, 772, 773, 774, 775, 780, 781, 782, 802, 803, 806, 811, 812, 813, 814, 816, 817, 818, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 838, 839, 884, 885, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 901, 902, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 948, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1031, 1032, 1034, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050]

print(len(ls_sm_cx))
print(len(ls_cx))
print(len(fr_indices))
# Out:
# 136
# 546
# 546

# %%
distance_x = 60
prominence_x = 400
width_x = 10
rel_height_x = 0.5
# wlen_x = 60

maxima, max_prop = find_peaks(ls_sm_cx, distance=distance_x, prominence=prominence_x, width=width_x, wlen=None, rel_height=rel_height_x)
maxima = maxima.tolist()
minima, min_prop = find_peaks(-np.array(ls_sm_cx), distance=distance_x, prominence=prominence_x, width=width_x, wlen=None, rel_height=rel_height_x)
minima = minima.tolist()
extrema_x = sorted(maxima + minima)

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(20, 7))

# plot ball position
ax.plot(list(range(len(ls_sm_cx))), ls_sm_cx, color='blue', label='x')

# plot extrema
for index in extrema_x:
    ax.axvline(x=index, color='r', linestyle='-')
ax.axvline(x=53, color='r', linestyle='-')

ax.set_title("Line Plot of X and Y coord")
ax.set_xlabel("Frame Index")
ax.set_ylabel("Value")
ax.legend()

# %% [markdown]
# # Normal find peaks

# %%
distance_x = int(0.4*120*1)
prominence_x = 343
width_x = 16
rel_height_x = 1
# wlen_x = 60
wlen_x = 400

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(20, 7), nrows=1, ncols=2)

# # smooth
# ls_coord = ls_sm_cx
# maxima_sm, max_prop_sm = find_peaks(ls_coord, distance=distance_x, prominence=prominence_x, width=width_x, wlen=None, rel_height=rel_height_x)
# maxima_sm = maxima_sm.tolist()
# minima_sm, min_prop_sm = find_peaks(-np.array(ls_coord), distance=distance_x, prominence=prominence_x, width=width_x, wlen=None, rel_height=rel_height_x)
# minima_sm = minima_sm.tolist()
# extrema_x_sm = sorted(maxima_sm + minima_sm)

# # plot ball position
# ax[0].plot(list(range(len(ls_sm_cx))), ls_sm_cx, color='blue', label='x')

# # plot extrema
# for index in extrema_x_sm:
#     ax[0].axvline(x=index, color='r', linestyle='-')
# # ax.axvline(x=53, color='r', linestyle='-')

# ax[0].set_title("Line Plot of X and Y coord")
# ax[0].set_xlabel("Frame Index")
# ax[0].set_ylabel("Value")
# ax[0].legend()


# non smooth
ls_coord = ls_cx
maxima, max_prop = find_peaks(ls_coord, distance=distance_x, prominence=prominence_x, width=width_x, wlen=wlen_x, rel_height=rel_height_x)
maxima = maxima.tolist()
minima, min_prop = find_peaks(-np.array(ls_coord), distance=distance_x, prominence=prominence_x, width=width_x, wlen=wlen_x, rel_height=rel_height_x)
minima = minima.tolist()
extrema_x = sorted(maxima + minima)

# plot ball position
ax[1].plot(list(range(len(ls_cx))), ls_cx, color='blue', label='x')
# ax[1].plot(fr_indices, ls_cx, color='blue', label='x')


# plot extrema
for index in extrema_x:
    ax[1].axvline(x=index, color='r', linestyle='-')

ax[1].set_title("Line Plot of X and Y coord")
ax[1].set_xlabel("Frame Index")
ax[1].set_ylabel("Value")
ax[1].legend()

plt.show()

# %%
for k, v in max_prop.items():
    print(k, ':', v[0])
print()

# for k, v in min_prop_sm.items():
#     print(k, ':', v[0])
# Out:
# prominences : 515.0
# left_bases : 0
# right_bases : 545
# widths : 456.8571428571429
# width_heights : 883.0
# left_ips : 88.14285714285714
# right_ips : 545.0

# %%
ls_cx[51]
# Out:
# 917

# %% [markdown]
# # Find peak cvt

# %%
width_x = 15

# Create a figure and axis object
fig, ax = plt.subplots(figsize=(20, 7), nrows=1, ncols=2)

# smooth
ls_coord = ls_sm_cx
maxima_sm= find_peaks_cwt(ls_coord, widths=width_x).tolist()
minima_sm = find_peaks_cwt(-np.array(ls_coord), widths=width_x).tolist()
extrema_x_sm = sorted(maxima_sm + minima_sm)

# plot ball position
ax[0].plot(list(range(len(ls_sm_cx))), ls_sm_cx, color='blue', label='x')

# plot extrema
for index in extrema_x_sm:
    ax[0].axvline(x=index, color='r', linestyle='-')
# ax.axvline(x=53, color='r', linestyle='-')

ax[0].set_title("Line Plot of X and Y coord")
ax[0].set_xlabel("Frame Index")
ax[0].set_ylabel("Value")
ax[0].legend()


# non smooth
ls_coord = ls_cx
maxima= find_peaks_cwt(ls_coord, widths=width_x).tolist()
minima = find_peaks_cwt(-np.array(ls_coord), widths=width_x).tolist()
extrema_x = sorted(maxima + minima)

# plot ball position
ax[1].plot(list(range(len(ls_cx))), ls_cx, color='blue', label='x')

# plot extrema
for index in extrema_x:
    ax[1].axvline(x=index, color='r', linestyle='-')

ax[1].set_title("Line Plot of X and Y coord")
ax[1].set_xlabel("Frame Index")
ax[1].set_ylabel("Value")
ax[1].legend()

plt.show()
